# %%
import urllib
import io
import numpy as np
import datetime 
import time
import pandas as pd
import datetime
import os
import requests
import json
import datetime
# today = datetime.datetime.now().weekday() + 1
# print(today)
# #class market(eu):
#    self.name=eu
#    self.stock=
#milan=market(milan)
#from indicies import eurstock
bvsp=[
'^BVSP',
'ABEV3.SA',
'ALLL3.SA',
'BBAS3.SA',
'BBDC4.SA',
'BBSE3.SA',
'BRFS3.SA',
'BRML3.SA',
'BRPR3.SA',
'BVMF3.SA',
'CCRO3.SA',
'CIEL3.SA',
'CMIG4.SA',
'CSAN3.SA',
'CSNA3.SA',
'ECOR3.SA',
'ELET3.SA',
'ESTC3.SA',
'GFSA3.SA',
'GGBR4.SA',
'GOLL4.SA',
'HYPE3.SA',
'ITSA4.SA',
'ITUB3.SA',
'JBSS3.SA',
'KROT3.SA',
'LAME4.SA',
'MRFG3.SA',
'MULT3.SA',
'PETR3.SA',
'PETR4.SA', 
'QUAL3.SA',
'SUZB5.SA',
'TIMP3.SA',
'VALE3.SA',
'VALE5.SA',
'USIM5.SA',
'BRKM5.SA',
'EMBR3.SA',
'KLBN11.SA',
'UGPA3.SA'
]

#https://query1.finance.yahoo.com/v7/finance/quote?symbols=UNP&fields=ebitda,shortRatio,priceToSales
#https://query1.finance.yahoo.com/v7/finance/quote?symbols=TLS.AX,MUS.AX

# url='https://query1.finance.yahoo.com/v8/finance/chart/cs.pa?&interval=30m&indicators=quote&includeTimestamps=true'


# oslo=['ORK.OL',
# 'TEL.OL', 
# 'MHG.OL',
# 'GJF.OL',
# 'SCHA.OL',                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Ads 
# # 'DNB.OL',
# 'STB.OL',
# 'YAR.OL',
# 'REC.OL',
# 'NANO.OL',
# 'SALM.OL',
# 'BAKKA.OL',
# 'LSG.OL',
# 'NAS.OL',
# 'GSF.OL',
# 'STL.OL',
# 'NHY.OL',
# 'TGS.OL',
# 'SUBC.OL',
# 'BWLPG.OL',

# #'ASKO.OL',
# 'AKERBP.OL',
# 'GOGL.OL',
# 'DNO.OL',
# 'PGS.OL'
# ]

gemany=['^GDAXI',
'ADS.DE',
'ALV.DE',
'BAS.DE',
'BAYN.DE',
'BEI.DE',
'BMW.DE',
'CBK.DE',
'DTG.DE',
'DB1.DE',
'DBK.DE',
'DPW.DE',
'DTE.DE',
'EOAN.DE',
#'FME.DE',
#'FRE.DE',
#'HEI.DE',
'HEN.DE',
'IFX.DE',
'LHA.DE',
#'LIN.DE',
'MRK.DE',
'MUV2.DE',
'PSM.DE',
'RWE.DE',
'SAP.DE',
'SIE.DE',
'TKA.DE',
'VNA.DE',
'VOW3.DE',
'CEC.DE',
'PAH3.DE',
'KGX.DE',
# 'DLG.DE',
'SDF.DE',
'1COV.DE',
'WAF.DE',
# 'OSR.DE',
'LXS.DE',
'BOSS.DE',
        

]
france=[

'ALO.PA',
'BNP.PA',
'CS.PA',
'ORA.PA',
'ACA.PA',
'EDF.PA',
'ENGI.PA',
'GLE.PA',
'VIV.PA',
'STLA.PA',
'CA.PA',
'WLN.PA',
'AF.PA',
'VK.PA',
'CGG.PA',
'SAN.PA',
'TTE.PA',
'RNO.PA',
'AIR.PA',
'SGO.PA',
'STM.PA',
'CO.PA',
'FR.PA',
'EO.PA',
'GET.PA',
'DG.PA',
'DSY.PA',
'UBI.PA',
'PUB.PA',
'BN.PA',
'MC.PA',
'EN.PA',
'SW.PA'
]
swiss=['ABBN.SW',
'ADEN.SW',
'AMS.SW',
'BAER.SW',
'CFR.SW',
'CSGN.SW',
'GEBN.SW',
'GIVN.SW',
'HOLN.SW',
'NESN.SW',
'NOVN.SW',
'ROG.SW',
'SCMN.SW',
'SGSN.SW',
'SLHN.SW',
'SREN.SW',
#'SYNN.SW',
'UBSG.SW',
'UHR.SW',
'ZURN.SW',
'CLN.SW',
]
milan=[
'ENI.MI',
'ENEL.MI',
'ISP.MI',
'UCG.MI',
# 'FCA.MI',
'G.MI',
'ATL.MI',
'TEN.MI',
'STM.MI',
'CNHI.MI',
'SRG.MI'
]
netherlands=[
'MT.AS',
'SHELL.AS',
'PNL.AS',
'AGN.AS',
'PHIA.AS',
'INGA.AS',
'KPN.AS',
'ABN.AS',
'AD.AS',
'UNA.AS',

]
uk=[
'LLOY.L',
'VOD.L',
'BP.L',
'BARC.L',
'MKS.L',
'GLEN.L',
'MRO.L',
'HSBA.L',
'PMO.L',
#'EVRH.L',
# 'TSCO.L',
#'BLT.L',
#'CNA.L',
'TCG.L',
'RBS.L',
'LGEN.L',
'TW.L',
'TLW.L',
'GNC.L',
'STAN.L',
'KGF.L',
'AV.L'


]
BR=[
'BPOST.BR',
'EURN.BR',
'PROX.BR',
'KBC.BR',
'ABI.BR',
'UMI.BR',
'FAGR.BR',
'AGS.BR',
'SOLB.BR'

]
proxy = '127.0.0.1:10809'
proxies = {
    'http': 'http://' + proxy,
    'https': 'https://' + proxy,}
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.137 Safari/537.36 LBBROWSER'
        } 

    #urlstr = 'http://chartapi.finance.yahoo.com/instrument/1.0/'+stock+'/chartdata;type=quote;range=1d/csv/'
    #    z=str(data).split('\\n')
    #    for eachLine in z:
    #        splitLine=eachLine.split(',')
    #        if len(splitLine)==6:
    #            if 'values' not in eachLine:
    #    
    ##                lineToWrite=eachLine+'\n'
    ##                print (splitLine)
    #                stklist.append(splitLine)
    #    beforeClose=float(stklist[-2][1])
    #    afterClose=float(stklist[-1][1])
    #    return float("%.3f"%(afterClose/beforeClose-1))
    #https://query1.finance.yahoo.com/v7/finance/quote?symbols=BAS.DE
    #for stock in eurstock:
    #    print (stock,bvspAfterclose(stock))

def getminbar(symbol,mins):

#     symbol='CS.PA'
    try:


        response = requests.get('https://query1.finance.yahoo.com/v8/finance/chart/'+symbol+'?&interval='+mins+'m&indicators=quote&includeTimestamps=true',headers=headers,proxies=proxies)
        data2=json.loads(response.text)
        
        time.sleep(3)
        try:
            close_list=data2['chart']['result'][0]['indicators']['quote'][0]['close']
            volume_list=data2['chart']['result'][0]['indicators']['quote'][0]['volume']
            meta=data2['chart']['result'][0]['meta']
            c_pre=meta['previousClose']
            timestamp=data2['chart']['result'][0]['timestamp']
            meta=data2['chart']['result'][0]['meta']
            dt_obj = datetime.datetime.fromtimestamp(timestamp[0]) 
            time1 =str(dt_obj)
            #     print time1[0:10]
#             print(close_list)
#             time.sleep(10)

            dir1='D:\\data\\min\\'+symbol+'\\'+time1[0:10]

            if not os.path.exists(dir1):
                os.makedirs(dir1)
            os.chdir(dir1)


            with open(time1[0:10]+'.txt',"w") as f:
                f.write(json.dumps(data2)) 

            #     global null
            clcopy=[]

            for c in close_list:
        #         print (c)
                if c!=None:
                    clcopy.append(c)
#             print(clcopy[-2])
  
    
            if symbol[-2:]=='SW':
#                 t=[clcopy[-3],c_pre,clcopy[-1]]
                return clcopy[-3],c_pre,clcopy[-1]
            else:
#                 t=[clcopy[-2],c_pre，clcopy[-1]]
#                 print(clcpoy[-2])
                return clcopy[-2],c_pre,clcopy[-1]
        except :
            print('Error+'+symbol)
    except requests.exceptions.ConnectionError as e:
        print('conectError',e.arg)



    #     data_dict=eval(data1)


def getdaybar(symbol,days):#str'1','5'
    #https://query1.finance.yahoo.com/v8/finance/chart/bayn.de?&interval=1d&indicators=quote&includeTimestamps=true
    
    try:
        
       
        response = requests.get('https://query1.finance.yahoo.com/v8/finance/chart/'+symbol+'?&interval='+days+'d&indicators=quote&includeTimestamps=true',headers=headers,proxies=proxies)
        data1=json.loads(response.text)
        time.sleep(3)
    except requests.exceptions.ConnectionError as e:
        print('Error',e.arg)
    

    
#     data_dict=eval(data1)

    close_list=data1['chart']['result'][0]['indicators']['quote'][0]['close']
    volume_list=data1['chart']['result'][0]['indicators']['quote'][0]['volume']
    meta=data1['chart']['result'][0]['meta']
#    c_pre=meta['previousClose']
    #
    #timestamp=data_dict['chart']['result'][0]['timestamp']
    timestamp=data1['chart']['result'][0]['meta']['currentTradingPeriod']['regular']['start']
#     print timestamp
    
   # meta=data_dict['chart']['result'][0]['meta']
    dt_obj = datetime.datetime.fromtimestamp(timestamp)
    time1 =str(dt_obj)
#     print time1[0:10]
    
    dir1='D:\\data\\Day\\'+symbol+'\\'+time1[0:10]
    
    if not os.path.exists(dir1):
        os.makedirs(dir1)
    os.chdir(dir1)
   
    
    with open(time1[0:10]+'.txt',"w") as f:
        f.write(json.dumps(data1) )



    return [close_list[-1],dt_obj]
def chg(market):
    
    
    result1=[]
    result2=[]
    symbolresult=[]
    errsymbol=[]
    
    print (datetime.datetime.now())
    for stk in market:
        textData=[]
        try:
            [before_c,yesterday_c,after_c]=(getminbar(stk,'1'))
#             print(stk,before_c,yesterday_c,after_c)
    #        before_c1=float(before_c)
    #        yesterday_c1=float(yesterday_c)
#             after_cList=getdaybar(stk,'1')
#             after_c=after_cList[0]
#             print (after_c)
#             day1=str(after_cList[1])[0:10]
            day1=time.strftime("%Y-%m-%d",time.localtime())
            #周五
            today = datetime.datetime.now().weekday() + 1
# print(today)
            if int(today)>6:
                day1=day1[0:9]+str(int(day1[9])+1)
                print(day1)

            chg=[after_c/float(before_c)-1,after_c/float(yesterday_c)-1]

    #        print type(before_c),type(yesterday_c),type(after_c)
    #        print before_c,yesterday_c,after_c
            print( 'symbol:%s,before_c:%.3f,after_c:%.3f,yesterday_c:%.3f,chgOnclose:%.3f,chgToday:%.3f'%(stk,before_c,after_c,yesterday_c,chg[0],chg[1]))
            data='symbol:%s,before_c:%.3f,after_c:%.3f,yesterday_c:%.3f,chgOnclose:%.3f,chgToday:%.3f'%(stk,before_c,after_c,yesterday_c,chg[0],chg[1])
            textData.append(data)
            result1.append(chg[0])
            result2.append(chg[1])
            symbolresult.append(stk)
            time.sleep(1)
            result=[result1,result2]
            os.chdir('d:\\data\\onClose')
            market1=market[-1][-2:]
            if market1=='SW':
                market1='SW'
            if not os.path.exists(market1):
                os.makedirs(market1)
                print ('%s is not exits' % market1)
            os.chdir(market1)
            if not os.path.exists(day1):
                os.makedirs(day1) 
            os.chdir(day1)
            fo = open(str(day1) + '.txt', 'a+')
            fo.write(str(textData) + '\n')
            fo.close()
        except :
            print(stk+':error!')
            errsymbol.append(stk)
            print(errsymbol)
    print(errsymbol)
            
    
# chg(netherlands)
for m in [swiss,gemany,france,netherlands,milan]:
#     pass
    chg(m)
# Out:
# 2022-03-05 10:12:37.123742
# symbol:ABBN.SW,before_c:29.080,after_c:28.880,yesterday_c:30.460,chgOnclose:-0.007,chgToday:-0.052
# symbol:ADEN.SW,before_c:39.090,after_c:38.980,yesterday_c:41.690,chgOnclose:-0.003,chgToday:-0.065
# symbol:AMS.SW,before_c:12.425,after_c:12.410,yesterday_c:13.250,chgOnclose:-0.001,chgToday:-0.063
# symbol:BAER.SW,before_c:47.600,after_c:47.510,yesterday_c:50.960,chgOnclose:-0.002,chgToday:-0.068
# symbol:CFR.SW,before_c:108.950,after_c:107.900,yesterday_c:114.600,chgOnclose:-0.010,chgToday:-0.058
# symbol:CSGN.SW,before_c:6.828,after_c:6.834,yesterday_c:7.298,chgOnclose:0.001,chgToday:-0.064
# symbol:GEBN.SW,before_c:583.000,after_c:581.400,yesterday_c:602.800,chgOnclose:-0.003,chgToday:-0.036
# symbol:GIVN.SW,before_c:3790.000,after_c:3778.000,yesterday_c:3798.000,chgOnclose:-0.003,chgToday:-0.005
# symbol:HOLN.SW,before_c:42.050,after_c:41.880,yesterday_c:44.830,chgOnclose:-0.004,chgToday:-0.066
# ...

# %%
chg(france)

# %%
chg(['STLA.PA'])

# %%
abbn=getdaybar('pub.pa','1')

# %%
abbn

# %%
abbn

# %%
d1='2022-02-04'

# %%
day[0:8]

# %%
print(time.strftime("%Y-%m-%d",time.localtime()))

# %%
symbol='rog.ch'

# %%
symbol[-2:]=='ch'
